# %%
import folium
import pandas as pd

# %%
# Visualizaçao de Mapa atraves de Coordenadas
mapa = folium.Map(location=[-15.788497,-47.879873],zoom_start=4)
folium.Marker([-19.9166813,-43.9344931]).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 
municipios = pd.read_excel('.\municipiosBrasil.xls',encoding='latin1')

lat=municipios['LATITUDE'][:500].values
long=municipios['LONGITUDE'][:500].values

mapa = folium.Map(location=[-15.788497,-47.879873],zoom_start=4)

for la, lo in zip(lat,long):
	folium.Marker([la,lo]).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
